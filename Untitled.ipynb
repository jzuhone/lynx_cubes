# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import h5py

# %%
chan, counts = np.loadtxt("spec.tab", unpack=True, skiprows=1)

# %%
f = h5py.File("spec_table.h5", "r")

# %%
spec = f["spec_table"][8,12,int(chan[0])-1:int(chan[-1])]

# %%
plt.figure(figsize=(10,6))
plt.plot(chan, counts)
plt.plot(chan, spec*1.0e-7)

# %%
f["kT"].shape
# Out:
# (199,)

# %%
f["vel"].shape
# Out:
# (81,)
